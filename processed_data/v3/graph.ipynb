# %%
import pandas as pd
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

file_path = 'train.csv'  
df = pd.read_csv(file_path)

# %%
df.hist(figsize=(15, 15), bins=100, xlabelsize=8, ylabelsize=8)
# Out:
# array([[<Axes: title={'center': 'manufactured'}>,
#         <Axes: title={'center': 'curb_weight'}>,
#         <Axes: title={'center': 'power'}>,
#         <Axes: title={'center': 'engine_cap'}>],
#        [<Axes: title={'center': 'no_of_owners'}>,
#         <Axes: title={'center': 'depreciation'}>,
#         <Axes: title={'center': 'coe'}>,
#         <Axes: title={'center': 'road_tax'}>],
#        [<Axes: title={'center': 'dereg_value'}>,
#         <Axes: title={'center': 'mileage'}>,
#         <Axes: title={'center': 'omv'}>, <Axes: title={'center': 'arf'}>],
#        [<Axes: title={'center': 'price'}>,
#         <Axes: title={'center': 'registration_year'}>, <Axes: >,
#         <Axes: >]], dtype=object)

# %%
y_train = df['price']

print(y_train.describe())
plt.figure()
sns.displot(y_train, bins=50)
# Out:
# count    2.500000e+04
# mean     1.151486e+05
# std      1.555725e+05
# min      7.000000e+02
# 25%      4.914100e+04
# 50%      7.888800e+04
# 75%      1.258000e+05
# max      2.899999e+06
# Name: price, dtype: float64
